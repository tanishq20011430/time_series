# %%
import pandas as pd

# %%
df = pd.read_csv("/content/daily-total-female-births-CA.csv")

# %%
df.head()
# Out:
#          date  births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['births'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
df.tail()
# Out:
#            date  births
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    365 non-null    object
#  1   births  365 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB

# %%
df['date'].dtype
# Out:
# dtype('O')

# %%
df_ = pd.read_csv("/content/daily-total-female-births-CA.csv",header =0,parse_dates=[0])

# %%
df_.head()
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44

# %%
df_['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# importing as series form
ser = pd.read_csv("/content/daily-total-female-births-CA.csv",header =0,parse_dates=[0],index_col=0,squeeze=True)
# Out:
# <ipython-input-14-9aa0755a6c22>:2: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   ser = pd.read_csv("/content/daily-total-female-births-CA.csv",header =0,parse_dates=[0],index_col=0,squeeze=True)

# %%
ser.head()
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# Name: births, dtype: int64

# %%
#exploring dataset
ser.shape
# Out:
# (365,)

# %%
df_.describe()
# Out:
#            births
# count  365.000000
# mean    41.980822
# std      7.348257
# min     23.000000
# 25%     37.000000
# 50%     42.000000
# 75%     46.000000
# max     73.000000

# %%
print(ser['1959-01'])
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# 1959-01-06    29
# 1959-01-07    45
# 1959-01-08    43
# 1959-01-09    38
# 1959-01-10    27
# 1959-01-11    38
# 1959-01-12    33
# 1959-01-13    55
# 1959-01-14    47
# 1959-01-15    45
# 1959-01-16    37
# 1959-01-17    50
# 1959-01-18    43
# 1959-01-19    41
# 1959-01-20    52
# 1959-01-21    34
# 1959-01-22    53
# 1959-01-23    39
# 1959-01-24    32
# 1959-01-25    37
# 1959-01-26    43
# 1959-01-27    39
# 1959-01-28    35
# 1959-01-29    44
# 1959-01-30    38
# 1959-01-31    24
# Name: births, dtype: int64

# %%
df_[(df_['date']>'1959-01-01')&(df_['date']<='1959-01-21')]
# Out:
#          date  births
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44
# 5  1959-01-06      29
# 6  1959-01-07      45
# 7  1959-01-08      43
# 8  1959-01-09      38
# 9  1959-01-10      27
# 10 1959-01-11      38
# 11 1959-01-12      33
# 12 1959-01-13      55
# 13 1959-01-14      47
# 14 1959-01-15      45
# 15 1959-01-16      37
# 16 1959-01-17      50
# 17 1959-01-18      43
# 18 1959-01-19      41
# 19 1959-01-20      52
# 20 1959-01-21      34

# %%
# Feature Engineering
features=df_
features['year']=df_['date'].dt.year

# %%
features['month']=df_['date'].dt.month

# %%
features['day']=df_['date'].dt.day

# %%
features.head()
# Out:
#         date  births  year  month  day
# 0 1959-01-01      35  1959      1    1
# 1 1959-01-02      32  1959      1    2
# 2 1959-01-03      30  1959      1    3
# 3 1959-01-04      31  1959      1    4
# 4 1959-01-05      44  1959      1    5

# %%
# Lag Features
features['lag1']=df_['births'].shift(1)

# %%
features['lag2']=df_['births'].shift(365)

# %%
features.head()
# Out:
#         date  births  year  month  day  lag1  lag2
# 0 1959-01-01      35  1959      1    1   NaN   NaN
# 1 1959-01-02      32  1959      1    2  35.0   NaN
# 2 1959-01-03      30  1959      1    3  32.0   NaN
# 3 1959-01-04      31  1959      1    4  30.0   NaN
# 4 1959-01-05      44  1959      1    5  31.0   NaN

# %%
#window feature:
features['Roll_mean']=df_['births'].rolling(window=2).mean()

# %%
features.head()
# Out:
#         date  births  year  month  day  lag1  lag2  Roll_mean
# 0 1959-01-01      35  1959      1    1   NaN   NaN        NaN
# 1 1959-01-02      32  1959      1    2  35.0   NaN       33.5
# 2 1959-01-03      30  1959      1    3  32.0   NaN       31.0
# 3 1959-01-04      31  1959      1    4  30.0   NaN       30.5
# 4 1959-01-05      44  1959      1    5  31.0   NaN       37.5

# %%
features['Roll_max']=df_['births'].rolling(window=3).max()

# %%
features.head()
# Out:
#         date  births  year  month  day  lag1  lag2  Roll_mean  Roll_max
# 0 1959-01-01      35  1959      1    1   NaN   NaN        NaN       NaN
# 1 1959-01-02      32  1959      1    2  35.0   NaN       33.5       NaN
# 2 1959-01-03      30  1959      1    3  32.0   NaN       31.0      35.0
# 3 1959-01-04      31  1959      1    4  30.0   NaN       30.5      32.0
# 4 1959-01-05      44  1959      1    5  31.0   NaN       37.5      44.0

# %%
#Expanding features:
features['expand_max']=df_['births'].expanding().max()

# %%
features.head(10)
# Out:
#         date  births  year  month  day  lag1  lag2  Roll_mean  Roll_max  \
# 0 1959-01-01      35  1959      1    1   NaN   NaN        NaN       NaN
# 1 1959-01-02      32  1959      1    2  35.0   NaN       33.5       NaN
# 2 1959-01-03      30  1959      1    3  32.0   NaN       31.0      35.0
# 3 1959-01-04      31  1959      1    4  30.0   NaN       30.5      32.0
# 4 1959-01-05      44  1959      1    5  31.0   NaN       37.5      44.0
# 5 1959-01-06      29  1959      1    6  44.0   NaN       36.5      44.0
# 6 1959-01-07      45  1959      1    7  29.0   NaN       37.0      45.0
# 7 1959-01-08      43  1959      1    8  45.0   NaN       44.0      45.0
# 8 1959-01-09      38  1959      1    9  43.0   NaN       40.5      45.0
# 9 1959-01-10      27  1959      1   10  38.0   NaN       32.5      43.0
#
#    expand_max
# 0        35.0
# 1        35.0
# 2        35.0
# 3        35.0
# 4        44.0
# 5        44.0
# 6        45.0
# 7        45.0
# 8        45.0
# 9        45.0

# %%
df=pd.read_csv("/content/us-airlines-monthly-aircraft-miles-flown.csv",header=0,parse_dates=[0])

# %%
df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %%
# Downsampalling :

quaterly_miles=df.resample('Q',on='Month').mean()

# %%
quaterly_miles.head()
# Out:
#                  MilesMM
# Month
# 1963-03-31   6696.333333
# 1963-06-30   8756.000000
# 1963-09-30  10392.333333
# 1963-12-31   7356.333333
# 1964-03-31   7287.666667

# %%
yearly_miles=df.resample('A',on='Month').sum()

# %%
yearly_miles.head()
# Out:
#             MilesMM
# Month
# 1963-12-31    99603
# 1964-12-31   106192
# 1965-12-31   115431
# 1966-12-31   119154
# 1967-12-31   126515

# %%
# Upsampalling:
upscaled_miles_df=df.resample('D',on='Month').mean()

# %%
upscaled_miles_df.head(35)
# Out:
#             MilesMM
# Month
# 1963-01-01   6827.0
# 1963-01-02      NaN
# 1963-01-03      NaN
# 1963-01-04      NaN
# 1963-01-05      NaN
# 1963-01-06      NaN
# 1963-01-07      NaN
# 1963-01-08      NaN
# 1963-01-09      NaN
# 1963-01-10      NaN
# 1963-01-11      NaN
# 1963-01-12      NaN
# 1963-01-13      NaN
# 1963-01-14      NaN
# 1963-01-15      NaN
# 1963-01-16      NaN
# 1963-01-17      NaN
# 1963-01-18      NaN
# 1963-01-19      NaN
# 1963-01-20      NaN
# 1963-01-21      NaN
# 1963-01-22      NaN
# 1963-01-23      NaN
# 1963-01-24      NaN
# 1963-01-25      NaN
# 1963-01-26      NaN
# 1963-01-27      NaN
# 1963-01-28      NaN
# 1963-01-29      NaN
# 1963-01-30      NaN
# 1963-01-31      NaN
# 1963-02-01   6178.0
# 1963-02-02      NaN
# 1963-02-03      NaN
# 1963-02-04      NaN

# %%
#filled nan values using below function
interpolated_miles_df = upscaled_miles_df.interpolate(method='linear')

# %%
interpolated_miles_df.head(32)
# Out:
#                 MilesMM
# Month
# 1963-01-01  6827.000000
# 1963-01-02  6806.064516
# 1963-01-03  6785.129032
# 1963-01-04  6764.193548
# 1963-01-05  6743.258065
# 1963-01-06  6722.322581
# 1963-01-07  6701.387097
# 1963-01-08  6680.451613
# 1963-01-09  6659.516129
# 1963-01-10  6638.580645
# 1963-01-11  6617.645161
# 1963-01-12  6596.709677
# 1963-01-13  6575.774194
# 1963-01-14  6554.838710
# 1963-01-15  6533.903226
# 1963-01-16  6512.967742
# 1963-01-17  6492.032258
# 1963-01-18  6471.096774
# 1963-01-19  6450.161290
# 1963-01-20  6429.225806
# 1963-01-21  6408.290323
# 1963-01-22  6387.354839
# 1963-01-23  6366.419355
# 1963-01-24  6345.483871
# 1963-01-25  6324.548387
# 1963-01-26  6303.612903
# 1963-01-27  6282.677419
# 1963-01-28  6261.741935
# 1963-01-29  6240.806452
# 1963-01-30  6219.870968
# 1963-01-31  6198.935484
# 1963-02-01  6178.000000

# %%
interpolated_miles_df.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
poly_interpolated_miles_df=upscaled_miles_df.interpolate(method='spline',order=2)

# %%
poly_interpolated_miles_df.plot()
# Out:
# <Axes: xlabel='Month'>
